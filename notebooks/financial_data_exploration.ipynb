# %%
import yfinance as yf

msft = yf.Ticker("MSFT")
print(msft)
"""
returns
<yfinance.Ticker object at 0x1a1715e898>
"""

# get stock info
msft.info
# Out:
# yfinance.Ticker object <MSFT>
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %%
# get historical market data, here max is 5 years.
msft.history(period="max")
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.056238    0.064508    0.056238    0.061751  1031788800
# 1986-03-14    0.061751    0.065059    0.061751    0.063956   308160000
# 1986-03-17    0.063956    0.065610    0.063956    0.065059   133171200
# 1986-03-18    0.065059    0.065610    0.062853    0.063405    67766400
# 1986-03-19    0.063405    0.063956    0.061751    0.062302    47894400
# ...                ...         ...         ...         ...         ...
# 2021-04-29  255.460007  256.100006  249.000000  252.509995    40589000
# 2021-04-30  249.740005  253.080002  249.600006  252.179993    30929200
# 2021-05-03  253.399994  254.350006  251.119995  251.860001    19626600
# 2021-05-04  250.970001  251.210007  245.759995  247.789993    32724400
# 2021-05-05  249.059998  249.498993  247.470001  247.919998     6976683
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# ...

# %%
import finnhub

# Setup client
finnhub_client = finnhub.Client(api_key="c29bdpiad3ib23jb8l50")

print(finnhub_client.forex_rates(base='USD'))
# Out:
# {'base': 'USD', 'quote': {'AED': 3.673200954750901, 'AFN': 77.50061732454954, 'ALL': 102.3749794988307, 'AMD': 520.880202405859, 'ANG': 1.7946561256661318, 'AOA': 654.273870645739, 'ARS': 93.71347232779225, 'AUD': 1.2969576681033441, 'AWG': 1.800999208259411, 'AZN': 1.7012815208079584, 'BAM': 1.6279318753429002, 'BBD': 2.0186446167051435, 'BDT': 84.7780478890664, 'BGN': 1.6273324502914286, 'BHD': 0.3769659268484978, 'BIF': 1958.9995146322153, 'BMD': 1, 'BND': 1.3352476083356712, 'BOB': 6.893395584734974, 'BRL': 5.444601886024321, 'BSD': 0.9997044501482327, 'BTC': 1.8631838961129783e-05, 'BTN': 73.83276623838302, 'BWP': 10.890640727102586, 'BYN': 2.567523150711276, 'BYR': 19599.995143824548, 'BZD': 2.015214573355057, 'CAD': 1.2304447983642357, 'CDF': 2000.9996678186171, 'CHF': 0.9138001799940224, 'CLF': 0.025506368474904485, 'CLP': 703.8018891879539, 'CNY': 6.473795551100569, 'COP': 3829.4990513266025, 'CRC': 616.0778528261642, 'CUC': 1, 'CUP': 26.499993755989045, 'CVE': 92.0502259915
# ...

# %%
print(finnhub_client.forex_rates(base='USD'))
# Out:
# {'base': 'USD', 'quote': {'AED': 3.673200954750901, 'AFN': 77.50061732454954, 'ALL': 102.3749794988307, 'AMD': 520.880202405859, 'ANG': 1.7946561256661318, 'AOA': 654.273870645739, 'ARS': 93.71347232779225, 'AUD': 1.2969576681033441, 'AWG': 1.800999208259411, 'AZN': 1.7012815208079584, 'BAM': 1.6279318753429002, 'BBD': 2.0186446167051435, 'BDT': 84.7780478890664, 'BGN': 1.6273324502914286, 'BHD': 0.3769659268484978, 'BIF': 1958.9995146322153, 'BMD': 1, 'BND': 1.3352476083356712, 'BOB': 6.893395584734974, 'BRL': 5.444601886024321, 'BSD': 0.9997044501482327, 'BTC': 1.8631838961129783e-05, 'BTN': 73.83276623838302, 'BWP': 10.890640727102586, 'BYN': 2.567523150711276, 'BYR': 19599.995143824548, 'BZD': 2.015214573355057, 'CAD': 1.2304447983642357, 'CDF': 2000.9996678186171, 'CHF': 0.9138001799940224, 'CLF': 0.025506368474904485, 'CLP': 703.8018891879539, 'CNY': 6.473795551100569, 'COP': 3829.4990513266025, 'CRC': 616.0778528261642, 'CUC': 1, 'CUP': 26.499993755989045, 'CVE': 92.0502259915
# ...

# %%
import requests
r = requests.get('https://finnhub.io/api/v1/forex/candle?symbol=OANDA:EUR_USD&resolution=1&from=1572651390&to=1575243390&token=c29bdpiad3ib23jb8l50')
print(r.json())
# Out:
# {'c': None, 'h': None, 'l': None, 'o': None, 's': 'no_data', 't': None, 'v': None}

# %%
print(finnhub_client.forex_candles('OANDA:EUR_USD', '5', 1590988249, 1591852249))
# Out:
# {'c': [1.11325, 1.1135, 1.11378, 1.11371, 1.11411, 1.11394, 1.11403, 1.11371, 1.11384, 1.1139, 1.11402, 1.1143, 1.11449, 1.11446, 1.11427, 1.11431, 1.11418, 1.11399, 1.11399, 1.11389, 1.11351, 1.11365, 1.114, 1.11423, 1.11372, 1.11339, 1.11355, 1.1133, 1.11349, 1.11353, 1.11418, 1.11494, 1.11455, 1.11481, 1.11369, 1.11325, 1.1127, 1.1122, 1.11248, 1.1133, 1.11336, 1.11333, 1.11355, 1.11342, 1.11385, 1.1139, 1.11384, 1.1137, 1.11336, 1.113, 1.11198, 1.11249, 1.11225, 1.11221, 1.11155, 1.11113, 1.11123, 1.11135, 1.11138, 1.11088, 1.11094, 1.11064, 1.11111, 1.11116, 1.11132, 1.11113, 1.11098, 1.11056, 1.11048, 1.11053, 1.11094, 1.11085, 1.11113, 1.11154, 1.11152, 1.11123, 1.111, 1.1114, 1.11132, 1.11127, 1.11133, 1.11113, 1.11139, 1.1115, 1.11153, 1.11151, 1.11169, 1.11131, 1.11066, 1.11062, 1.11072, 1.11056, 1.11018, 1.11093, 1.111, 1.11088, 1.11075, 1.11042, 1.11124, 1.11183, 1.11179, 1.1115, 1.11161, 1.1117, 1.11215, 1.11246, 1.11211, 1.11252, 1.11288, 1.11349, 1.11364, 1.11263, 1.11
# ...

# %%
print(finnhub_client.forex_candles('OANDA:XAU_USD', '5', 1590988249, 1591852249))
# Out:
# {'c': [1741.455, 1742.247, 1741.853, 1741.936, 1742.082, 1742.979, 1743.2, 1743.275, 1743.68, 1743.373, 1742.415, 1742.906, 1741.653, 1741.609, 1742.506, 1742.058, 1742.453, 1741.798, 1741.505, 1741.496, 1740.229, 1740.755, 1740.259, 1740.119, 1740.034, 1739.283, 1739.975, 1740.599, 1740.556, 1739.866, 1737.329, 1737.869, 1738.469, 1739.807, 1739.403, 1741.88, 1742.303, 1740.192, 1739.675, 1738.06, 1738.282, 1738.443, 1737.434, 1737.336, 1735.823, 1736.46, 1736.805, 1736.902, 1737.293, 1737.585, 1737.83, 1736.507, 1733.859, 1735.096, 1734.686, 1735.92, 1735.673, 1735.785, 1734.82, 1734.27, 1733.745, 1734.105, 1734.974, 1733.267, 1735.627, 1733.497, 1734.24, 1733.936, 1734.851, 1734.314, 1733.611, 1732.168, 1732.584, 1732.102, 1730.319, 1728.814, 1730.277, 1732.449, 1733.52, 1733.473, 1733.037, 1734.289, 1734.089, 1732.881, 1731.43, 1732.706, 1734.273, 1734.058, 1732.993, 1735.463, 1734.98, 1734.955, 1733.647, 1732.99, 1732.2, 1729.532, 1730.474, 1731.35, 1731.843, 1732.831, 1733.421,
# ...

# %%
# !pip install websocket-client
# Out:
# ...
#      |████████████████████████████████| 67 kB 5.8 MB/s eta 0:00:011
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/ask/PycharmProjects/pytorch_m1/pytorch_m1/bin/python -m pip install --upgrade pip' command.

# %%
#https://pypi.org/project/websocket_client/
import websocket

def on_message(ws, message):
    print(f"received: {message}\n")

def on_error(ws, error):
    print(error)

def on_close(ws):
    print("### closed ###")

def on_open(ws):
    ws.send('{"type":"subscribe","symbol":"OANDA:EUR_USD"}')
    #ws.send('{"type":"subscribe","symbol":"AMZN"}')
    #ws.send('{"type":"subscribe","symbol":"BINANCE:BTCUSDT"}')
    #ws.send('{"type":"subscribe","symbol":"IC MARKETS:1"}')

if __name__ == "__main__":
    websocket.enableTrace(True)
    websocket.setdefaulttimeout(5)
    ws = websocket.WebSocketApp("wss://ws.finnhub.io?token=c29bdpiad3ib23jb8l50",
                              on_message = on_message,
                              on_error = on_error,
                              on_close = on_close)
    ws.on_open = on_open
    ws.run_forever()
# Out:
# --- request header ---
# GET /?token=c29bdpiad3ib23jb8l50 HTTP/1.1
# Upgrade: websocket
# Host: ws.finnhub.io
# Origin: http://ws.finnhub.io
# Sec-WebSocket-Key: k36fLS/OUDxls6T+EWaDhQ==
# Sec-WebSocket-Version: 13
# Connection: Upgrade
# Cookie: __cfduid=d6f0a717ea162c17a7775394b748794781620231194
#
#
# -----------------------
# --- response header ---
# HTTP/1.1 101 Switching Protocols
# Date: Wed, 05 May 2021 16:21:56 GMT
# Connection: upgrade
# Upgrade: websocket
# Sec-WebSocket-Accept: lsQQjkrdG6k7RQSw+07sXRq/puc=
# CF-Cache-Status: DYNAMIC
# cf-request-id: 09deef12b20000dd0688243000000001
# Expect-CT: max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"
# Report-To: {"max_age":604800,"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report?s=N5F20dUJQX1%2Bh5K0zkUX5oYRT5RkhUQHvcOC5vsaTezTTG%2BZKE8dqxDAjxonW%2FpOZEqmdWNb3oYDRheTwdKDs5SIdINXxFvlSm8tkBes"}],"group":"cf-nel"}
# NEL: {"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# ...
