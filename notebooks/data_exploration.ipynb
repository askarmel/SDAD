# %%
import pandas as pd

# read the data
df_train = pd.read_csv('../data/artificialNoAnomaly/art_daily_no_noise.csv')
df_test = pd.read_csv('../data/artificialNoAnomaly/art_daily_no_noise.csv')
# get the image pixel values and labels
train_date = df_train.iloc[:, 0]
train_value = df_train.iloc[:, 1:]
test_date = df_test.iloc[:, 0]
test_value = df_test.iloc[:, 1:]

# %%
df_train.plot()
# Out:
# <AxesSubplot:>

# %%
df_ano_train = pd.read_csv('../data/artificialWithAnomaly/art_load_balancer_spikes.csv')

df_ano_train.plot()
# Out:
# <AxesSubplot:>

# %%
df_ano2_train = pd.read_csv('../data/realAdExchange/exchange-4_cpc_results.csv')
df_ano2_train.plot()
# Out:
# <AxesSubplot:>

# %%
df_ano3_train = pd.read_csv('../data/realAWSCloudwatch/ec2_cpu_utilization_53ea38.csv')
df_ano3_train.plot()
# Out:
# <AxesSubplot:>

# %%
df_ano4_train = pd.read_csv('../data/realTraffic/speed_t4013.csv')
df_ano4_train.plot()
# Out:
# <AxesSubplot:>

# %%
df_ano5_train = pd.read_csv('../data/realTweets/Twitter_volume_AAPL.csv')
df_ano5_train.plot()
# Out:
# <AxesSubplot:>
